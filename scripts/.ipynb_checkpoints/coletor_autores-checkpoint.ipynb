# %%
import json
import networkx as nx
import numpy as np
import os
from src.authorship_util import get_authors_api
from pathlib import Path 

INSTITUICOES = ['uft', 'ufnt', 'ceulp', 'ifto', 'unitins', 'tocantins']

# %%
def load_network_data(institution, year):
    """Carrega os dados da rede a partir do arquivo JSON"""
    file_path = f'../results/metrics/{institution}/{institution}_{year}.json'
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# %%
ids = set()
for instituicao in INSTITUICOES:
    data = load_network_data(instituicao, 2024)
    degrees = data['degrees']
    betweenness_centrality = data['betweenness_centrality']
    closeness_centrality = data['closeness_centrality']
    eigenvector_centrality = data['eigenvector_centrality']
    metrics = {
        'degrees' : sorted(degrees.items(), key=lambda item: item[1], reverse=True),
        'betweenness_centrality' : sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse=True),
        'closeness_centrality' : sorted(closeness_centrality.items(), key=lambda item: item[1], reverse=True),
        'eigenvector_centrality' : sorted(eigenvector_centrality.items(), key=lambda item: item[1], reverse=True),
    }
    for _, metric in metrics.items():
        ids.update([item[0] for item in metric[:10]])

# %%
authors = []

# %%
def chunk_list(input_list, chunk_size):
    chunks = []
    for i in range(0, len(input_list), chunk_size):
        chunks.append(input_list[i:i + chunk_size])
    return chunks

chunk_size = 10
chunks = chunk_list(list(ids), chunk_size)
for chunk in chunks:
    authors.extend(get_authors_api(chunk))

# %%
with open(Path("../results/top_authors_info.json"), "w") as f:
    json.dump(authors, f)

# %%
import json
from collections import defaultdict

# Load the network metrics data for each institution
def load_network_data(institution, year=2024):
    """Carrega os dados da rede a partir do arquivo JSON"""
    file_path = f'../results/metrics/{institution}/{institution}_{year}.json'
    with open(file_path, 'r') as f:
        return json.load(f)

# Load all institutions data
INSTITUICOES = ['uft', 'ufnt', 'ceulp', 'ifto', 'unitins', 'tocantins']
institution_metrics = {}
for instituicao in INSTITUICOES:
    institution_metrics[instituicao] = load_network_data(instituicao)

# Load authors data
with open('../results/top_authors_info.json', 'r') as f:
    authors_data = json.load(f)

# Create a dictionary for quick author lookup
authors_dict = {author['id']: author for author in authors_data}

# Map institution codes to full names
INSTITUTION_NAMES = {
    'uft': 'Universidade Federal do Tocantins',
    'ufnt': 'Universidade Federal do Norte do Tocantins',
    'ceulp': 'Centro Universitário Luterano de Palmas',
    'ifto': 'Instituto Federal do Tocantins',
    'unitins': 'Universidade do Tocantins',
    'tocantins': 'Universidade do Tocantins'
}

# Define the metrics we'll use (translated to Portuguese)
# 'eigenvector_centrality' (Autovetor) has been removed as requested.
metrics = {
    'degrees': 'Grau',
    'betweenness_centrality': 'Intermediação',
    'closeness_centrality': 'Proximidade'
}

# Function to format numbers with comma as decimal separator
def format_number(value):
    if isinstance(value, float):
        return f"{value:,.4f}".replace(".", ",").replace(",0000", "")
    elif isinstance(value, int):
        return f"{value}"
    return str(value)

# Generate LaTeX tables for each institution
for inst_code, metrics_data in institution_metrics.items():
    institution_name = INSTITUTION_NAMES.get(inst_code, inst_code)
    
    print(f"% Table for {institution_name}")
    print("\\rowcolors{0}{}{}")
    print("\\begin{table}[!htpb]")
    print("    \\centering")
    print(f"    \\caption{{Top 3 pesquisadores da {institution_name.replace('Universidade', 'Univ.').replace('Federal', 'Fed.')} por métricas de centralidade.}}")
    print(f"    \\label{{tb:top_centrality_{inst_code}}}")
    print("    \\footnotesize")
    print("    \\scalebox{0.85}{")
    print("        \\begin{tabular}{ >{\centering\arraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }")
    print("        \\hline")
    print("        \\textbf{Métrica} & \\textbf{Pesquisador} & \\textbf{Works} & \\textbf{h-index} & \\textbf{Valor} & \\textbf{Curso} \\\\ \\hline")
    
    # For each metric, get top 3 authors
    for metric, metric_name in metrics.items():
        # Get the metric values and sort them
        metric_values = metrics_data.get(metric, {})
        sorted_items = sorted(metric_values.items(), key=lambda x: x[1], reverse=True)[:3]
        
        # Print the first row with metric name
        if len(sorted_items) > 0:
            author_id, value = sorted_items[0]
            # h_index is part of the author's data, so it's accessed via authors_dict
            author = authors_dict.get(author_id, {'display_name': 'Desconhecido', 'works_count': '?', 'h_index': '?'})
            formatted_value = format_number(value)
            print(f"        \\multirow{{3}}{{*}}{{{metric_name}}} & \\cellcolor{{lightgray}}{author['display_name']} & \\cellcolor{{lightgray}}{author.get('works_count', '?')} & \\cellcolor{{lightgray}}{author.get('h_index', '?')} & \\cellcolor{{lightgray}}{formatted_value} & \\cellcolor{{lightgray}} \\\\")
        
        # Print the remaining two rows
        for i in range(1, 3):
            if i < len(sorted_items):
                author_id, value = sorted_items[i]
                # h_index is part of the author's data, so it's accessed via authors_dict
                author = authors_dict.get(author_id, {'display_name': 'Desconhecido', 'works_count': '?', 'h_index': '?'})
                formatted_value = format_number(value)
                if i % 2 == 1:  # Alternate coloring
                    print(f"          & {author['display_name']} & {author.get('works_count', '?')} & {author.get('summary_stats', '?').h_index} & {formatted_value} & \\\\")
                else:
                    print(f"          & \\cellcolor{{lightgray}}{author['display_name']} & \\cellcolor{{lightgray}}{author.get('works_count', '?')} & \\cellcolor{{lightgray}}{author.get('h_index', '?')} & \\cellcolor{{lightgray}}{formatted_value} & \\cellcolor{{lightgray}} \\\\")
            else:
                print("          & & & & & \\\\")
        
        # Add hline after each metric except the last one
        if metric != list(metrics.keys())[-1]:  # Check if it's the last metric in the *modified* list
            print("        \\hline")
    
    print("        \\end{tabular}")
    print("    }")
    print("\\end{table}")
    print("\\rowcolors{2}{lightgray}{}")
    print("\n\n")
# Out:
# % Table for Universidade Federal do Tocantins
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Univ. Fed. do Tocantins por métricas de centralidade.}
#     \label{tb:top_centrality_uft}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Gil Rodrigues dos Santos & \cellcolor{lightgray}333 & \cellcolor{lightgray}? & \cellcolor{lightgray}491 & \cellcolor{lightgray} \\
#           & Renato Almeida Sarmento & 235 & ? & 399 & \\
#           & \cellcolor{lightgray}Raimundo Wagner de Souza Aguiar & \cellcolor{lightgray}159 & \cellcolor{lightgray}? & \cellcolor{lightgray}380 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Raphael Sânzio Pimenta & \cellcolor{lightgray}108 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0514 & \cellcolor{lightgray} \\
#           & Paula B. Morais & 110 & ? & 0,0395 & \\
#           & \cellcolor{lightgray}Joênes Mucci Pelúzio & \cellcolor{lightgray}254 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0343 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Raphael Sânzio Pimenta & \cellcolor{lightgray}108 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,2411 & \cellcolor{lightgray} \\
#           & Paula B. Morais & 110 & ? & 0,2369 & \\
#           & \cellcolor{lightgray}Joênes Mucci Pelúzio & \cellcolor{lightgray}254 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,2353 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
#
#
#
# % Table for Universidade Federal do Norte do Tocantins
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Univ. Fed. do Norte do Tocantins por métricas de centralidade.}
#     \label{tb:top_centrality_ufnt}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Konnery Kazelly Marinho & \cellcolor{lightgray}10 & \cellcolor{lightgray}? & \cellcolor{lightgray}66 & \cellcolor{lightgray} \\
#           & Wagner dos Santos Mariano & 77 & ? & 66 & \\
#           & \cellcolor{lightgray}Ulisses Gaspar Neiss & \cellcolor{lightgray}879 & \cellcolor{lightgray}? & \cellcolor{lightgray}61 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Wagner dos Santos Mariano & \cellcolor{lightgray}77 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,1297 & \cellcolor{lightgray} \\
#           & Sandro Estevan Moron & 69 & ? & 0,1034 & \\
#           & \cellcolor{lightgray}Luisa Sousa Machado & \cellcolor{lightgray}7 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0897 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Wagner dos Santos Mariano & \cellcolor{lightgray}77 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,1143 & \cellcolor{lightgray} \\
#           & Sandro Estevan Moron & 69 & ? & 0,1100 & \\
#           & \cellcolor{lightgray}Marco Aurélio Miranda Soares & \cellcolor{lightgray}6 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,1027 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
#
#
#
# % Table for Centro Universitário Luterano de Palmas
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Centro Universitário Luterano de Palmas por métricas de centralidade.}
#     \label{tb:top_centrality_ceulp}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Érika da Silva Maciel & \cellcolor{lightgray}169 & \cellcolor{lightgray}? & \cellcolor{lightgray}81 & \cellcolor{lightgray} \\
#           & Fernando Rodrigues Peixoto Quaresma & 133 & ? & 72 & \\
#           & \cellcolor{lightgray}Luís Fernando Castagnino Sesti & \cellcolor{lightgray}32 & \cellcolor{lightgray}? & \cellcolor{lightgray}34 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Érika da Silva Maciel & \cellcolor{lightgray}169 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0709 & \cellcolor{lightgray} \\
#           & Heitor S. Ribeiro & 94 & ? & 0,0581 & \\
#           & \cellcolor{lightgray}Bibiano Madrid & \cellcolor{lightgray}36 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0574 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Érika da Silva Maciel & \cellcolor{lightgray}169 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,1144 & \cellcolor{lightgray} \\
#           & Fernando Rodrigues Peixoto Quaresma & 133 & ? & 0,1054 & \\
#           & \cellcolor{lightgray}Heitor S. Ribeiro & \cellcolor{lightgray}94 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,1045 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
#
#
#
# % Table for Instituto Federal do Tocantins
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Instituto Fed. do Tocantins por métricas de centralidade.}
#     \label{tb:top_centrality_ifto}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Marcelo Mendes Pedroza & \cellcolor{lightgray}71 & \cellcolor{lightgray}? & \cellcolor{lightgray}114 & \cellcolor{lightgray} \\
#           & Kenia Regina Streich & 4 & ? & 101 & \\
#           & \cellcolor{lightgray}Mário César Sedrez & \cellcolor{lightgray}18 & \cellcolor{lightgray}? & \cellcolor{lightgray}101 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Raimundo Laerton de Lima Leite & \cellcolor{lightgray}23 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0308 & \cellcolor{lightgray} \\
#           & Marcelo Mendes Pedroza & 71 & ? & 0,0249 & \\
#           & \cellcolor{lightgray}Weimar Silva Castilho & \cellcolor{lightgray}63 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0187 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Raimundo Laerton de Lima Leite & \cellcolor{lightgray}23 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0931 & \cellcolor{lightgray} \\
#           & Weimar Silva Castilho & 63 & ? & 0,0914 & \\
#           & \cellcolor{lightgray}Antônio Clementino dos Santos & \cellcolor{lightgray}235 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0909 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
#
#
#
# % Table for Universidade do Tocantins
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Univ. do Tocantins por métricas de centralidade.}
#     \label{tb:top_centrality_unitins}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Lílian Natália Ferreira de Lima & \cellcolor{lightgray}80 & \cellcolor{lightgray}? & \cellcolor{lightgray}128 & \cellcolor{lightgray} \\
#           & Janayna Araújo Viana & 55 & ? & 84 & \\
#           & \cellcolor{lightgray}Adriana Malvásio & \cellcolor{lightgray}83 & \cellcolor{lightgray}? & \cellcolor{lightgray}83 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Darlene Teixeira Castro & \cellcolor{lightgray}32 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0634 & \cellcolor{lightgray} \\
#           & Sarah Gisele de Vasconcelos Leite & 5 & ? & 0,0535 & \\
#           & \cellcolor{lightgray}Lílian Natália Ferreira de Lima & \cellcolor{lightgray}80 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0493 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Darlene Teixeira Castro & \cellcolor{lightgray}32 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0789 & \cellcolor{lightgray} \\
#           & Lílian Natália Ferreira de Lima & 80 & ? & 0,0763 & \\
#           & \cellcolor{lightgray}Francisco Alves Lima Júnior & \cellcolor{lightgray}54 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0753 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
#
#
#
# % Table for Universidade do Tocantins
# \rowcolors{0}{}{}
# \begin{table}[!htpb]
#     \centering
#     \caption{Top 3 pesquisadores da Univ. do Tocantins por métricas de centralidade.}
#     \label{tb:top_centrality_tocantins}
#     \footnotesize
#     \scalebox{0.85}{
#         \begin{tabular}{ >{\centeringrraybackslash}m{2.5cm} | L{4.5cm} | R{1.2cm} | R{1.2cm} | R{1.2cm} | L{2cm} }
#         \hline
#         \textbf{Métrica} & \textbf{Pesquisador} & \textbf{Works} & \textbf{h-index} & \textbf{Valor} & \textbf{Curso} \\ \hline
#         \multirow{3}{*}{Grau} & \cellcolor{lightgray}Gil Rodrigues dos Santos & \cellcolor{lightgray}333 & \cellcolor{lightgray}? & \cellcolor{lightgray}498 & \cellcolor{lightgray} \\
#           & Renato Almeida Sarmento & 235 & ? & 406 & \\
#           & \cellcolor{lightgray}Raimundo Wagner de Souza Aguiar & \cellcolor{lightgray}159 & \cellcolor{lightgray}? & \cellcolor{lightgray}381 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Intermediação} & \cellcolor{lightgray}Raphael Sânzio Pimenta & \cellcolor{lightgray}108 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0407 & \cellcolor{lightgray} \\
#           & Joênes Mucci Pelúzio & 254 & ? & 0,0313 & \\
#           & \cellcolor{lightgray}Paula B. Morais & \cellcolor{lightgray}110 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,0308 & \cellcolor{lightgray} \\
#         \hline
#         \multirow{3}{*}{Proximidade} & \cellcolor{lightgray}Raphael Sânzio Pimenta & \cellcolor{lightgray}108 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,2168 & \cellcolor{lightgray} \\
#           & Paula B. Morais & 110 & ? & 0,2127 & \\
#           & \cellcolor{lightgray}Joênes Mucci Pelúzio & \cellcolor{lightgray}254 & \cellcolor{lightgray}? & \cellcolor{lightgray}0,2122 & \cellcolor{lightgray} \\
#         \end{tabular}
#     }
# \end{table}
# \rowcolors{2}{lightgray}{}
